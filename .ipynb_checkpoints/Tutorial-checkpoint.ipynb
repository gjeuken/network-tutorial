# %% [markdown]
# # Load libraries

# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt

# %% [markdown]
# # Create a network object with NetworkX

# %%
network_df1 = pd.read_csv('data/N1.txt', sep=' ', header = None)

network1 = nx.Graph()
network1.add_edges_from(network_df1.values)

nx.draw(network1, node_size = 5, edge_color = 'gray')

network1.Degree()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-51-2d9c87fb3386> in <module>()
#       6 nx.draw(network1, node_size = 5, edge_color = 'gray')
#       7
# ----> 8 network1.Degree()
#
# AttributeError: 'Graph' object has no attribute 'Degree'

# %%
network_df2 = pd.read_csv('data/N2.txt', sep=' ', header = None)

network2 = nx.Graph()
network2.add_edges_from(network_df2.values)

nx.draw(network2, node_size = 5, edge_color = 'gray')

# %%
network_df3 = pd.read_csv('data/N3.txt', sep=' ', header = None)

network3 = nx.Graph()
network3.add_edges_from(network_df3.values)

nx.draw(network3, node_size = 5, edge_color = 'gray')

# %% [markdown]
# In the data/ directory, there are three files (N1.txt, N2.txt, N3.txt). One is a social network of email exchanges at a Spanish university [1], one is the Western States power grid [2], and one is the (largest cluster of the) protein interaction network in yeast [3].
#
# Your task now it to use the tools above to decide which network corresponds to which file.
#
#
#
#
# ### References
#
# [1] R. Guimer, L. Danon, A. Daz-Guilera, F. Giralt, and A. Arenas. Self-
# similar community structure in a network of human interactions. Physical
# Review E, 68(6):065103, December 2003.
#
# [2] Duncan J. Watts and Steven H. Strogatz. Collective dynamics of ‘small-
# world’ networks. Nature, 393(6684):440–442, June 1998.
#
# [3] H. Jeong, S. P. Mason, A.-L. Barabasi, and Z. N. Oltvai. Lethality and
# centrality in protein networks. Nature, 411(6833):41–42, May 2001.
